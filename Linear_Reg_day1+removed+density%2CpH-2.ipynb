# %% [markdown]
# Linear Regression with Wine data

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import sklearn
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
cd downloads
# Out:
# /Users/apple/Downloads

# %%
df = pd.read_csv('wine.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.keys()
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
wine=pd.DataFrame(df)

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
Y=wine["quality"]
print(Y)
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
# 5       5
# 6       5
# 7       7
# 8       7
# 9       5
# 10      5
# 11      5
# 12      5
# 13      5
# 14      5
# 15      5
# 16      7
# 17      5
# 18      4
# 19      6
# 20      6
# 21      5
# 22      5
# 23      5
# 24      6
# 25      5
# 26      5
# 27      5
# 28      5
# 29      6
#        ..
# 1569    6
# 1570    6
# 1571    6
# 1572    5
# 1573    6
# 1574    6
# 1575    6
# 1576    6
# 1577    6
# 1578    6
# 1579    5
# 1580    6
# 1581    5
# 1582    5
# 1583    5
# 1584    7
# 1585    6
# 1586    6
# 1587    6
# 1588    6
# 1589    5
# 1590    6
# 1591    6
# 1592    6
# 1593    6
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
X=wine.drop(['quality','pH','density'], axis=1)
print(X)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %%
lm=linear_model.LinearRegression()
lm.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print('Coefficients: \n', lm.coef_)
# Out:
# Coefficients:
#  [ 0.03546451 -1.14390052 -0.16672362  0.00827318 -1.61569043  0.00376039
#  -0.00288763  0.88694323  0.28366964]

# %%
lm.intercept_, lm.coef_
# Out:
# (2.6442991345252684,
#  array([ 0.03546451, -1.14390052, -0.16672362,  0.00827318, -1.61569043,
#          0.00376039, -0.00288763,  0.88694323,  0.28366964]))

# %%
lm.predict(X)[0:5]
# Out:
# array([ 5.10530037,  5.06108475,  5.17222309,  5.70744482,  5.10530037])

# %%
# Run Regression using statmodels

import statsmodels.api as sm
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# /Users/apple/anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                quality   R-squared:                       0.986
# Model:                            OLS   Adj. R-squared:                  0.986
# Method:                 Least Squares   F-statistic:                 1.250e+04
# Date:                Mon, 18 Sep 2017   Prob (F-statistic):               0.00
# Time:                        14:59:42   Log-Likelihood:                -1633.4
# No. Observations:                1599   AIC:                             3285.
# Df Residuals:                    1590   BIC:                             3333.
# Df Model:                           9
# ...

# %% [markdown]
# Compute VIF Factors

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns

# %%
vif.round(1)
# Out:
#    VIF Factor              features
# 0        37.6         fixed acidity
# 1        15.7      volatile acidity
# 2         8.6           citric acid
# 3         4.7        residual sugar
# 4         5.9             chlorides
# 5         6.4   free sulfur dioxide
# 6         6.0  total sulfur dioxide
# 7        21.2             sulphates
# 8        37.1               alcohol

# %%
#Linear regression models are a key part of the family of supervised learning models.The cars dataset gives Speed and Stopping Distances of Cars. This dataset is a data frame with 50 rows and 2 variables. The rows refer to wine and the variables refer to content of the wine based on the wine parameter 
#the quality of the wine can be understood and predicted with various permutations and combination methodology. summary output above shows 11 variables,based on this predictors we esimate which variable have a strong power to predict the quality of outcome. The coefficient

# %%
predictions
# Out:
# 0       4.977035
# 1       5.194411
# 2       5.209031
# 3       5.623421
# 4       4.977035
# 5       5.011387
# 6       4.968073
# 7       5.213337
# 8       5.172989
# 9       5.653235
# 10      4.809367
# 11      5.653235
# 12      5.005665
# 13      5.814767
# 14      5.358344
# 15      5.401200
# 16      5.826386
# 17      5.531969
# 18      4.768679
# 19      5.341855
# 20      5.280631
# 21      5.310261
# 22      5.513276
# 23      5.126171
# 24      5.322413
# 25      4.975383
# 26      5.164569
# 27      5.513276
# 28      4.934653
# 29      5.277562
#           ...
# 1569    5.883120
# 1570    6.489396
# 1571    5.939422
# 1572    4.820737
# 1573    6.288623
# 1574    5.091950
# 1575    6.082922
# 1576    5.883535
# 1577    5.933351
# 1578    5.800924
# 1579    5.857953
# 1580    6.224591
# 1581    5.857953
# 1582    5.837541
# 1583    5.134441
# 1584    6.247350
# 1585    6.218071
# 1586    6.339023
# 1587    5.617671
# 1588    6.565388
# 1589    4.702544
# ...
